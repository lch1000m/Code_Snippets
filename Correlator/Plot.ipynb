# %%
import goldentiger as gt
import pandas as pd

# %% [markdown]
# # Heatmap

# %%
df = pd.read_excel(
    r'C:\Codes\Snippets\sample data\aliasing.xlsx',
    sheetname='heatmap',
    index_col='Space',
)

df
# Out:
#        W140  W200  W500
# Space
# S100      3     2   1.0
# S200      4     3   2.0
# S300      5     4   3.5
# S500      7     5   4.0
# S1000    10     7   4.5

# %%
import seaborn as sns
# %matplotlib inline

# %%
sns.heatmap(df, annot=True)

# %% [markdown]
# # Distribution Plot

# %%
df = pd.read_excel(
    r'C:\Codes\Snippets\sample data\aliasing.xlsx',
    sheetname='dist',
)

# %%
sns.distplot(df['POR'])

# %%
df2 = pd.read_excel(
    r'C:\Codes\Snippets\sample data\aliasing.xlsx',
    sheetname='dist',
)

# %%
sns.set()
sns.swarmplot(x='item', y='value', data=df2)

# %%
sp1 = df2[df2['item'] == 'POR']['value']
sp2 = df2[df2['item'] == 'New']['value']

sns.kdeplot(sp1, label='0', color='b', shade=True, cbar=True)
sns.kdeplot(sp2, label='10', color='g', shade=True)

# %%
df3 = pd.read_excel(
    r'C:\Codes\Snippets\sample data\aliasing.xlsx',
    sheetname='pair',
)

# %%
g = sns.pairplot(df3)

# %%
g = sns.stripplot(x='item', y='value', data=df2)

# %%
g = sns.stripplot(x='item', y='value', data=df2, jitter=True)
